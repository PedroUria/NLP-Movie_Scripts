# %%
import pandas as pd

df = pd.read_csv("movies_with_feats.csv", index_col=0)
df[df.columns[:20]].head()
# Out:
#                                                                       Processed Title  \
# Avatar                                                                         Avatar
# The Dark Knight Rises                                          Dark-Knight-Rises,-The
# The Avengers                                                            Avengers,-The
# Pirates of the Caribbean: Dead Man's Chest  Pirates-of-the-Caribbean-Dead-Man's-Chest
# Men in Black 3                                                         Men-in-Black-3
#
#                                             Success  FK_read_level_char_1  \
# Avatar                                            1                     2
# The Dark Knight Rises                             1                     2
# The Avengers                                      1                     2
# Pirates of the Caribbean: Dead Man's Chest        1                     2
# Men in Black 3                                    1                     2
#
#                                             FK_read_level_char_2  \
# Avatar                                                         2
# The Dark Knight Rises                                          2
# The Avengers                                                   3
# Pirates of the Caribbean: Dead Man's Chest                     1
# Men in Black 3                                                 3
#
#                                             FK_read_level_char_3  \
# Avatar                                                         2
# The Dark Knight Rises                                          3
# The Avengers                                                   3
# Pirates of the Caribbean: Dead Man's Chest                     1
# Men in Black 3                                                 2
#
#                                             FK_read_level_char_4  \
# Avatar                                                         3
# The Dark Knight Rises                                          2
# The Avengers                                                   4
# Pirates of the Caribbean: Dead Man's Chest                     1
# Men in Black 3                                                 3
#
#                                             FK_read_level_char_5  \
# Avatar                                                         3
# The Dark Knight Rises                                          2
# The Avengers                                                   3
# Pirates of the Caribbean: Dead Man's Chest                     4
# Men in Black 3                                                 4
#
#                                             n_stop_words_char_1  \
# Avatar                                                      139
# The Dark Knight Rises                                       130
# The Avengers                                                141
# Pirates of the Caribbean: Dead Man's Chest                  132
# Men in Black 3                                              196
#
#                                             n_stop_words_char_2  \
# Avatar                                                      124
# The Dark Knight Rises                                       117
# The Avengers                                                135
# Pirates of the Caribbean: Dead Man's Chest                  114
# Men in Black 3                                              158
#
#                                             n_stop_words_char_3  \
# Avatar                                                       84
# The Dark Knight Rises                                       121
# The Avengers                                                 97
# Pirates of the Caribbean: Dead Man's Chest                   98
# Men in Black 3                                               77
#
#                                             n_stop_words_char_4  \
# Avatar                                                      101
# The Dark Knight Rises                                       107
# The Avengers                                                 96
# Pirates of the Caribbean: Dead Man's Chest                  103
# Men in Black 3                                               79
#
#                                             n_stop_words_char_5  \
# Avatar                                                       94
# The Dark Knight Rises                                       121
# The Avengers                                                 68
# Pirates of the Caribbean: Dead Man's Chest                   86
# Men in Black 3                                               67
#
#                                             n_curse_words_char_1  \
# Avatar                                                        16
# The Dark Knight Rises                                          0
# The Avengers                                                   0
# Pirates of the Caribbean: Dead Man's Chest                     0
# Men in Black 3                                                 7
#
#                                             n_curse_words_char_2  \
# Avatar                                                         9
# The Dark Knight Rises                                          2
# The Avengers                                                   0
# Pirates of the Caribbean: Dead Man's Chest                     0
# Men in Black 3                                                 4
#
#                                             n_curse_words_char_3  \
# Avatar                                                         1
# The Dark Knight Rises                                          0
# The Avengers                                                   1
# Pirates of the Caribbean: Dead Man's Chest                     0
# Men in Black 3                                                 0
#
#                                             n_curse_words_char_4  \
# Avatar                                                         5
# The Dark Knight Rises                                          0
# The Avengers                                                   0
# Pirates of the Caribbean: Dead Man's Chest                     0
# Men in Black 3                                                 0
#
#                                             n_curse_words_char_5  \
# Avatar                                                         6
# The Dark Knight Rises                                          0
# The Avengers                                                   0
# Pirates of the Caribbean: Dead Man's Chest                     0
# Men in Black 3                                                 2
#
#                                             n_mentions_others_char_1  \
# Avatar                                                            35
# The Dark Knight Rises                                             34
# The Avengers                                                      36
# Pirates of the Caribbean: Dead Man's Chest                        20
# Men in Black 3                                                   180
#
#                                             n_mentions_others_char_2  \
# Avatar                                                            26
# The Dark Knight Rises                                             36
# The Avengers                                                      20
# Pirates of the Caribbean: Dead Man's Chest                         8
# Men in Black 3                                                    88
#
#                                             n_mentions_others_char_3
# Avatar                                                            10
# The Dark Knight Rises                                              5
# The Avengers                                                      18
# Pirates of the Caribbean: Dead Man's Chest                         2
# Men in Black 3                                                    17

# %%
df[df.columns[20:]].head()
# Out:
#                                             n_mentions_others_char_4  \
# Avatar                                                             2
# The Dark Knight Rises                                             26
# The Avengers                                                      11
# Pirates of the Caribbean: Dead Man's Chest                         1
# Men in Black 3                                                    16
#
#                                             n_mentions_others_char_5  \
# Avatar                                                             1
# The Dark Knight Rises                                             19
# The Avengers                                                       2
# Pirates of the Caribbean: Dead Man's Chest                         2
# Men in Black 3                                                    11
#
#                                             main_char_rel_diag_length  \
# Avatar                                                      39.537232
# The Dark Knight Rises                                       23.705825
# The Avengers                                                30.146047
# Pirates of the Caribbean: Dead Man's Chest                  36.743621
# Men in Black 3                                              57.328163
#
#                                             stdvs_unique_words_above_mean
# Avatar                                                          -0.090538
# The Dark Knight Rises                                            0.255438
# The Avengers                                                    -0.118151
# Pirates of the Caribbean: Dead Man's Chest                      -0.481995
# Men in Black 3                                                   0.742729

# %%
df["FK_read_level_mean_char"] = (df["FK_read_level_char_1"] + df["FK_read_level_char_2"] + 
                                 df["FK_read_level_char_3"] + df["FK_read_level_char_4"] + 
                                 df["FK_read_level_char_5"])/5
del df["FK_read_level_char_1"], df["FK_read_level_char_2"], df["FK_read_level_char_3"]
del df["FK_read_level_char_4"], df["FK_read_level_char_5"]

# %%
def get_stdvs_above_mean(feat_general_name):
    n_all = df[feat_general_name + "1"]
    for i in range(2, 6):
        n_all += df[feat_general_name + str(i)]
        del df[feat_general_name + str(i)]
    n_all_mean = n_all.mean()
    n_all_std = n_all.std()
    df["stdvs_" + feat_general_name[:-5] + "above_mean"] = (n_all - n_all_mean)/n_all_std
    del df[feat_general_name + "1"]

# %%
get_stdvs_above_mean("n_stop_words_char_")
get_stdvs_above_mean("n_curse_words_char_")
get_stdvs_above_mean("n_mentions_others_char_")

# %%
df.head()
# Out:
#                                                                       Processed Title  \
# Avatar                                                                         Avatar
# The Dark Knight Rises                                          Dark-Knight-Rises,-The
# The Avengers                                                            Avengers,-The
# Pirates of the Caribbean: Dead Man's Chest  Pirates-of-the-Caribbean-Dead-Man's-Chest
# Men in Black 3                                                         Men-in-Black-3
#
#                                             Success  \
# Avatar                                            1
# The Dark Knight Rises                             1
# The Avengers                                      1
# Pirates of the Caribbean: Dead Man's Chest        1
# Men in Black 3                                    1
#
#                                             main_char_rel_diag_length  \
# Avatar                                                      39.537232
# The Dark Knight Rises                                       23.705825
# The Avengers                                                30.146047
# Pirates of the Caribbean: Dead Man's Chest                  36.743621
# Men in Black 3                                              57.328163
#
#                                             stdvs_unique_words_above_mean  \
# Avatar                                                          -0.090538
# The Dark Knight Rises                                            0.255438
# The Avengers                                                    -0.118151
# Pirates of the Caribbean: Dead Man's Chest                      -0.481995
# Men in Black 3                                                   0.742729
#
#                                             FK_read_level_mean_char  \
# Avatar                                                          2.4
# The Dark Knight Rises                                           2.2
# The Avengers                                                    3.0
# Pirates of the Caribbean: Dead Man's Chest                      1.8
# Men in Black 3                                                  2.8
#
#                                             stdvs_n_stop_words_above_mean  \
# Avatar                                                           0.063141
# The Dark Knight Rises                                            0.789323
# The Avengers                                                    -0.004098
# Pirates of the Caribbean: Dead Man's Chest                      -0.057889
# Men in Black 3                                                   0.533814
#
#                                             stdvs_n_curse_words_above_mean  \
# Avatar                                                            0.106202
# The Dark Knight Rises                                            -0.686754
# The Avengers                                                     -0.709410
# Pirates of the Caribbean: Dead Man's Chest                       -0.732066
# Men in Black 3                                                   -0.437539
#
#                                             stdvs_n_mentions_others_above_mean
# Avatar                                                               -0.541956
# The Dark Knight Rises                                                -0.176310
# The Avengers                                                         -0.438622
# Pirates of the Caribbean: Dead Man's Chest                           -0.867858
# Men in Black 3                                                        1.349863
